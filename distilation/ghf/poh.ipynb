# %%
import pandas as pd

# %%
import polars as pl

pl.read_csv(r"output\huggingface_models_1000likes_700.0pm10000.0M_params.csv").to_pandas().sort_values(["likes", "parameters"], ascending=False)
# Out:
#                          _id                                         id  \
# 0   678dc6fff905d106be796d8a                    deepseek-ai/DeepSeek-R1
# 1   661f97d48e7f3438386f755d                 meta-llama/Meta-Llama-3-8B
# 2   676ca1388118866906abbd7c                         hexgrad/Kokoro-82M
# 3   64b02a230c8415cd4a159fff              meta-llama/Llama-2-7b-chat-hf
# 4   657607b0a90ae2daaef65917       mistralai/Mixtral-8x7B-Instruct-v0.1
# 5   64aa630b73790912c790894e                      meta-llama/Llama-2-7b
# 6   6698d8a0653e4babe21e1e7d           meta-llama/Llama-3.1-8B-Instruct
# 7   661f97d0b00f5f1f620c4f25        meta-llama/Meta-Llama-3-8B-Instruct
# 8   676c000762cee1f3abc3ed5f                    deepseek-ai/DeepSeek-V3
# 9   650aedb6238a644cb93a52c3                  mistralai/Mistral-7B-v0.1
# 10  6796251e22990ae89b1f60f1                   deepseek-ai/Janus-Pro-7B
# 11  65c5577b1080431ea9e083cd                            google/gemma-7b
# ...
